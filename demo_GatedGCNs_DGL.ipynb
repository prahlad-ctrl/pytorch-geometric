# %% [markdown]
# # Lab demo : GatedGCNs with DGL
#
# Xavier Bresson, 23 October 2019
#
# Deep Graph Library (DGL)
# https://docs.dgl.ai/ <br>
#
# Residual Gated Graph ConvNets, X Bresson, T Laurent, ICLR 2018, [arXiv:1711.07553](https://arxiv.org/pdf/1711.07553v2.pdf) <br>

# %%
# Install DGL
# !pip install dgl==0.4
# Out:
# Collecting dgl==0.4
#   Downloading dgl-0.4-cp37-cp37m-manylinux1_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 26.4 MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from dgl==0.4) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from dgl==0.4) (1.4.1)
# Requirement already satisfied: networkx>=2.1 in /usr/local/lib/python3.7/dist-packages (from dgl==0.4) (2.6.3)
# Installing collected packages: dgl
# Successfully installed dgl-0.4

# %%
# Import libs
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

import dgl
from dgl import DGLGraph
from dgl.data import MiniGCDataset

import time

import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Collate function to prepare graphs

# %%
# collate function
def collate(samples):
    graphs, labels = map(list, zip(*samples)) # samples is a list of pairs (graph, label).
    labels = torch.tensor(labels)
    tab_sizes_n = [ graphs[i].number_of_nodes() for i in range(len(graphs))] # graph sizes
    tab_snorm_n = [ torch.FloatTensor(size,1).fill_(1./float(size)) for size in tab_sizes_n ]
    snorm_n = torch.cat(tab_snorm_n).sqrt() # graph size normalization
    tab_sizes_e = [ graphs[i].number_of_edges() for i in range(len(graphs))] # nb of edges
    tab_snorm_e = [ torch.FloatTensor(size,1).fill_(1./float(size)) for size in tab_sizes_e ]
    snorm_e = torch.cat(tab_snorm_e).sqrt() # graph size normalization
    batched_graph = dgl.batch(graphs) # batch graphs
    return batched_graph, labels, snorm_n, snorm_e


# create artifical data feature (= in degree) for each node
def create_artificial_features(dataset):
    for (graph,_) in dataset:
        graph.ndata['feat'] = graph.in_degrees().view(-1, 1).float()
        graph.edata['feat'] = torch.ones(graph.number_of_edges(),1)
    return dataset


# generate artifical graph dataset with DGL
trainset = MiniGCDataset(350, 10, 20)
testset = MiniGCDataset(100, 10, 20)
valset = MiniGCDataset(100, 10, 20)
trainset = create_artificial_features(trainset)
testset = create_artificial_features(testset)
valset = create_artificial_features(valset)
print(trainset[0])
# Out:
# (DGLGraph(num_nodes=12, num_edges=36,
#          ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}), 0)

# %% [markdown]
# # Visualize graph dataset

# %%
visualset = MiniGCDataset(8, 10, 20)

# visualise the 8 classes of graphs
for c in range(8):
    graph, label = visualset[c]
    fig, ax = plt.subplots()
    nx.draw(graph.to_networkx(), ax=ax)
    ax.set_title('Class: {:d}'.format(label))
    plt.show()

# %% [markdown]
# # Implement GatedGCNs with DGL
#
#
# Residual Gated Graph ConvNets, X Bresson, T Laurent, ICLR 2017, [arXiv:1711.07553](https://arxiv.org/pdf/1711.07553v2.pdf) <br>
#
#
# \begin{eqnarray}
# h_i^{\ell+1} &=& h_i^{\ell} + \text{ReLU} \left( A^\ell h_i^{\ell} +  \sum_{j\sim i} \eta(e_{ij}^{\ell}) \odot B^\ell h_j^{\ell} \right), \quad \eta(e_{ij}^{\ell}) = \frac{\sigma(e_{ij}^{\ell})}{\sum_{j'\sim i} \sigma(e_{ij'}^{\ell}) + \varepsilon} \\
# e_{ij}^{\ell+1} &=& e^\ell_{ij} + \text{ReLU} \Big( C^\ell e_{ij}^{\ell} + D^\ell h^{\ell+1}_i + E^\ell h^{\ell+1}_j  \Big)
# \end{eqnarray}

# %%
class MLP_layer(nn.Module):

    def __init__(self, input_dim, output_dim, L=2): # L = nb of hidden layers
        super(MLP_layer, self).__init__()
        list_FC_layers = [ nn.Linear( input_dim, input_dim, bias=True ) for l in range(L) ]
        list_FC_layers.append(nn.Linear( input_dim, output_dim , bias=True ))
        self.FC_layers = nn.ModuleList(list_FC_layers)
        self.L = L

    def forward(self, x):
        y = x
        for l in range(self.L):
            y = self.FC_layers[l](y)
            y = torch.relu(y)
        y = self.FC_layers[self.L](y)
        return y



class GatedGCN_layer(nn.Module):

    def __init__(self, input_dim, output_dim):
        super(GatedGCN_layer, self).__init__()
        self.A = nn.Linear(input_dim, output_dim, bias=True)
        self.B = nn.Linear(input_dim, output_dim, bias=True)
        self.C = nn.Linear(input_dim, output_dim, bias=True)
        self.D = nn.Linear(input_dim, output_dim, bias=True)
        self.E = nn.Linear(input_dim, output_dim, bias=True)
        self.bn_node_h = nn.BatchNorm1d(output_dim)
        self.bn_node_e = nn.BatchNorm1d(output_dim)

    def message_func(self, edges):
        Bh_j = edges.src['Bh']
        e_ij = edges.data['Ce'] +  edges.src['Dh'] + edges.dst['Eh'] # e_ij = Ce_ij + Dhi + Ehj
        edges.data['e'] = e_ij
        return {'Bh_j' : Bh_j, 'e_ij' : e_ij}

    def reduce_func(self, nodes):
        Ah_i = nodes.data['Ah']
        Bh_j = nodes.mailbox['Bh_j']
        e = nodes.mailbox['e_ij']
        sigma_ij = torch.sigmoid(e) # sigma_ij = sigmoid(e_ij)
        h = Ah_i + torch.sum( sigma_ij * Bh_j, dim=1 ) / torch.sum( sigma_ij, dim=1 )  # hi = Ahi + sum_j eta_ij * Bhj
        return {'h' : h}

    def forward(self, g, h, e, snorm_n, snorm_e):

        h_in = h # residual connection
        e_in = e # residual connection

        g.ndata['h']  = h
        g.ndata['Ah'] = self.A(h)
        g.ndata['Bh'] = self.B(h)
        g.ndata['Dh'] = self.D(h)
        g.ndata['Eh'] = self.E(h)
        g.edata['e']  = e
        g.edata['Ce'] = self.C(e)
        g.update_all(self.message_func,self.reduce_func)
        h = g.ndata['h'] # result of graph convolution
        e = g.edata['e'] # result of graph convolution

        h = h* snorm_n # normalize activation w.r.t. graph node size
        e = e* snorm_e # normalize activation w.r.t. graph edge size

        h = self.bn_node_h(h) # batch normalization
        e = self.bn_node_e(e) # batch normalization

        h = torch.relu(h) # non-linear activation
        e = torch.relu(e) # non-linear activation

        h = h_in + h # residual connection
        e = e_in + e # residual connection

        return h, e


class GatedGCN_Net(nn.Module):

    def __init__(self, net_parameters):
        super(GatedGCN_Net, self).__init__()
        input_dim = net_parameters['input_dim']
        hidden_dim = net_parameters['hidden_dim']
        output_dim = net_parameters['output_dim']
        L = net_parameters['L']
        self.embedding_h = nn.Linear(input_dim, hidden_dim)
        self.embedding_e = nn.Linear(1, hidden_dim)
        self.GatedGCN_layers = nn.ModuleList([ GatedGCN_layer(hidden_dim, hidden_dim) for _ in range(L) ])
        self.MLP_layer = MLP_layer(hidden_dim, output_dim)

    def forward(self, g, h, e, snorm_n, snorm_e):

        # input embedding
        h = self.embedding_h(h)
        e = self.embedding_e(e)

        # graph convnet layers
        for GGCN_layer in self.GatedGCN_layers:
            h,e = GGCN_layer(g,h,e,snorm_n,snorm_e)

        # MLP classifier
        g.ndata['h'] = h
        y = dgl.mean_nodes(g,'h')
        y = self.MLP_layer(y)

        return y

    def loss(self, y_scores, y_labels):
        loss = nn.CrossEntropyLoss()(y_scores, y_labels)
        return loss

    def accuracy(self, scores, targets):
        scores = scores.detach().argmax(dim=1)
        acc = (scores==targets).float().sum().item()
        return acc

    def update(self, lr):
        update = torch.optim.Adam( self.parameters(), lr=lr )
        return update





# network parameters
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 100
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 2

# instantiate network
net = GatedGCN_Net(net_parameters)
print(net)
# Out:
# GatedGCN_Net(
#   (embedding_h): Linear(in_features=1, out_features=100, bias=True)
#   (embedding_e): Linear(in_features=1, out_features=100, bias=True)
#   (GatedGCN_layers): ModuleList(
#     (0): GatedGCN_layer(
#       (A): Linear(in_features=100, out_features=100, bias=True)
#       (B): Linear(in_features=100, out_features=100, bias=True)
#       (C): Linear(in_features=100, out_features=100, bias=True)
#       (D): Linear(in_features=100, out_features=100, bias=True)
#       (E): Linear(in_features=100, out_features=100, bias=True)
#       (bn_node_h): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_node_e): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): GatedGCN_layer(
#       (A): Linear(in_features=100, out_features=100, bias=True)
#       (B): Linear(in_features=100, out_features=100, bias=True)
#       (C): Linear(in_features=100, out_features=100, bias=True)
#       (D): Linear(in_features=100, out_features=100, bias=True)
#       (E): Linear(in_features=100, out_features=100, bias=True)
#       (bn_node_h): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (bn_node_e): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (MLP_layer): MLP_layer(
#     (FC_layers): ModuleList(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Linear(in_features=100, out_features=100, bias=True)
#       (2): Linear(in_features=100, out_features=8, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Test forward pass

# %%
train_loader = DataLoader(trainset, batch_size=10, shuffle=True, collate_fn=collate)
batch_graphs, batch_labels, batch_snorm_n, batch_snorm_e = list(train_loader)[0]
print(batch_graphs)
print(batch_labels)
print(batch_snorm_n.size())
print(batch_snorm_e.size())

batch_x = batch_graphs.ndata['feat']
print('batch_x',batch_x.size())

batch_e = batch_graphs.edata['feat']
print('batch_e',batch_e.size())

batch_snorm_n = batch_snorm_n
print('batch_snorm_n',batch_snorm_n.size())

batch_snorm_e = batch_snorm_e
print('batch_snorm_e',batch_snorm_e.size())

batch_scores = net.forward(batch_graphs, batch_x, batch_e, batch_snorm_n, batch_snorm_e)
print(batch_scores.size())

batch_labels = batch_labels
accuracy = net.accuracy(batch_scores,batch_labels)
print(accuracy)
# Out:
# DGLGraph(num_nodes=139, num_edges=503,
#          ndata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float32)})
# tensor([0, 0, 5, 1, 1, 2, 5, 0, 3, 7])
# torch.Size([139, 1])
# torch.Size([503, 1])
# batch_x torch.Size([139, 1])
# batch_e torch.Size([503, 1])
# batch_snorm_n torch.Size([139, 1])
# batch_snorm_e torch.Size([503, 1])
# torch.Size([10, 8])
# 2.0

# %% [markdown]
# # Test backward pass

# %%
# optimization parameters
opt_parameters = {}
opt_parameters['lr'] = 0.0005

# Loss
loss = net.loss(batch_scores, batch_labels)

# Backward pass
lr = opt_parameters['lr']
optimizer = torch.optim.Adam(net.parameters(), lr=1e-3)
optimizer.zero_grad()
loss.backward()
optimizer.step()

# %% [markdown]
# # Train one epoch

# %%
def train_one_epoch(net, data_loader):
    """
    train one epoch
    """
    net.train()
    epoch_loss = 0
    epoch_train_acc = 0
    nb_data = 0
    gpu_mem = 0
    for iter, (batch_graphs, batch_labels, batch_snorm_n, batch_snorm_e) in enumerate(data_loader):
        batch_x = batch_graphs.ndata['feat']
        batch_e = batch_graphs.edata['feat']
        batch_snorm_n = batch_snorm_n
        batch_snorm_e = batch_snorm_e
        batch_labels = batch_labels
        batch_scores = net.forward(batch_graphs, batch_x, batch_e, batch_snorm_n, batch_snorm_e)
        loss = net.loss(batch_scores, batch_labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.detach().item()
        epoch_train_acc += net.accuracy(batch_scores,batch_labels)
        nb_data += batch_labels.size(0)
    epoch_loss /= (iter + 1)
    epoch_train_acc /= nb_data
    return epoch_loss, epoch_train_acc

# %% [markdown]
# # Evaluation

# %%
def evaluate_network(net, data_loader):
    """
    evaluate test set
    """
    net.eval()
    epoch_test_loss = 0
    epoch_test_acc = 0
    nb_data = 0
    with torch.no_grad():
        for iter, (batch_graphs, batch_labels, batch_snorm_n, batch_snorm_e) in enumerate(data_loader):
            batch_x = batch_graphs.ndata['feat']
            batch_e = batch_graphs.edata['feat']
            batch_snorm_n = batch_snorm_n
            batch_snorm_e = batch_snorm_e
            batch_labels = batch_labels
            batch_scores = net.forward(batch_graphs, batch_x, batch_e, batch_snorm_n, batch_snorm_e)
            loss = net.loss(batch_scores, batch_labels)
            epoch_test_loss += loss.detach().item()
            epoch_test_acc += net.accuracy(batch_scores,batch_labels)
            nb_data += batch_labels.size(0)
        epoch_test_loss /= (iter + 1)
        epoch_test_acc /= nb_data
    return epoch_test_loss, epoch_test_acc

# %% [markdown]
# # Train GNN

# %%
# datasets
train_loader = DataLoader(trainset, batch_size=50, shuffle=True, collate_fn=collate)
test_loader = DataLoader(testset, batch_size=50, shuffle=False, collate_fn=collate)
val_loader = DataLoader(valset, batch_size=50, shuffle=False, drop_last=False, collate_fn=collate)

# Create model
net_parameters = {}
net_parameters['input_dim'] = 1
net_parameters['hidden_dim'] = 100
net_parameters['output_dim'] = 8 # nb of classes
net_parameters['L'] = 4
net = GatedGCN_Net(net_parameters)

optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

epoch_train_losses = []
epoch_test_losses = []
epoch_val_losses = []
epoch_train_accs = []
epoch_test_accs = []
epoch_val_accs = []
for epoch in range(50):

    start = time.time()
    epoch_train_loss, epoch_train_acc = train_one_epoch(net, train_loader)
    epoch_test_loss, epoch_test_acc = evaluate_network(net, test_loader)
    epoch_val_loss, epoch_val_acc = evaluate_network(net, val_loader)

    print('Epoch {}, time {:.4f}, train_loss: {:.4f}, test_loss: {:.4f}, val_loss: {:.4f} \n                     train_acc: {:.4f}, test_acc: {:.4f}, val_acc: {:.4f}'.format(epoch, time.time()-start, epoch_train_loss, epoch_test_loss, epoch_val_loss, epoch_train_acc, epoch_test_acc, epoch_val_acc))
# Out:
# Epoch 0, time 3.6863, train_loss: 2.0995, test_loss: 2.0495, val_loss: 2.0598
#                      train_acc: 0.2400, test_acc: 0.3200, val_acc: 0.2900
# Epoch 1, time 3.9175, train_loss: 1.9245, test_loss: 1.9491, val_loss: 1.9528
#                      train_acc: 0.3486, test_acc: 0.3600, val_acc: 0.3600
# Epoch 2, time 2.9829, train_loss: 1.8078, test_loss: 1.8720, val_loss: 1.8707
#                      train_acc: 0.4943, test_acc: 0.3200, val_acc: 0.3300
# Epoch 3, time 1.9571, train_loss: 1.7302, test_loss: 1.7959, val_loss: 1.7910
#                      train_acc: 0.4600, test_acc: 0.3300, val_acc: 0.4000
# Epoch 4, time 1.9226, train_loss: 1.6618, test_loss: 1.7131, val_loss: 1.7062
#                      train_acc: 0.4514, test_acc: 0.4300, val_acc: 0.4400
# Epoch 5, time 1.9341, train_loss: 1.5926, test_loss: 1.6296, val_loss: 1.6241
#                      train_acc: 0.4714, test_acc: 0.4400, val_acc: 0.4500
# Epoch 6, time 1.9325, train_loss: 1.5375, test_loss: 1.5459, val_loss: 1.5407
#                      train_acc: 0.5371, test_acc: 0.5100, val_acc: 0.5200
# Epoch 7, time 2.0155, train_loss: 1.4682, test_loss: 1.4715, val_loss: 1.4671
#                      train_acc: 0.6314, test_acc: 0.6200, val_acc: 0.6100
# Epoch 8, time 1.9383, train_loss: 1.4172, test_loss: 1.4066, val_loss: 1.4023
#                      train_acc: 0.7286, test_acc: 0.6500, val_acc: 0.6600
# Epoch 9, time 1.9826, train_loss: 1.3407, test_loss: 1.3437, val_loss: 1.3414
#                      train_acc: 0.7514, test_acc: 0.7800, val_acc: 0.8300
# Epoch 10, time 1.9440, train_loss: 1.2989, test_loss: 1.2690, val_loss: 1.2665
#                      train_acc: 0.7514, test_acc: 0.7800, val_acc: 0.8200
# Epoch 11, time 1.9270, train_loss: 1.2157, test_loss: 1.2083, val_loss: 1.2071
#                      train_acc: 0.7571, test_acc: 0.7700, val_acc: 0.8100
# Epoch 12, time 1.9502, train_loss: 1.1661, test_loss: 1.1430, val_loss: 1.1428
#                      train_acc: 0.7771, test_acc: 0.8100, val_acc: 0.8400
# Epoch 13, time 1.9312, train_loss: 1.0886, test_loss: 1.0817, val_loss: 1.0839
#                      train_acc: 0.7857, test_acc: 0.7900, val_acc: 0.8000
# Epoch 14, time 1.9305, train_loss: 1.0509, test_loss: 1.0418, val_loss: 1.0428
#                      train_acc: 0.7829, test_acc: 0.7700, val_acc: 0.8100
# Epoch 15, time 1.9495, train_loss: 0.9882, test_loss: 0.9772, val_loss: 0.9813
#                      train_acc: 0.7943, test_acc: 0.8500, val_acc: 0.8500
# Epoch 16, time 1.9724, train_loss: 0.9681, test_loss: 0.9314, val_loss: 0.9369
#                      train_acc: 0.7686, test_acc: 0.8100, val_acc: 0.8500
# Epoch 17, time 1.9558, train_loss: 0.9405, test_loss: 0.8884, val_loss: 0.8911
#                      train_acc: 0.7914, test_acc: 0.8100, val_acc: 0.8600
# Epoch 18, time 2.0365, train_loss: 0.8621, test_loss: 0.8354, val_loss: 0.8396
#                      train_acc: 0.7829, test_acc: 0.7900, val_acc: 0.8500
# Epoch 19, time 1.9257, train_loss: 0.8154, test_loss: 0.8067, val_loss: 0.8125
#                      train_acc: 0.8086, test_acc: 0.8100, val_acc: 0.8600
# Epoch 20, time 1.9098, train_loss: 0.8074, test_loss: 0.7640, val_loss: 0.7682
#                      train_acc: 0.8229, test_acc: 0.8300, val_acc: 0.8900
# Epoch 21, time 1.9125, train_loss: 0.7531, test_loss: 0.7157, val_loss: 0.7199
#                      train_acc: 0.8171, test_acc: 0.8200, val_acc: 0.8900
# Epoch 22, time 1.9799, train_loss: 0.7619, test_loss: 0.7029, val_loss: 0.7129
#                      train_acc: 0.8000, test_acc: 0.8400, val_acc: 0.8800
# Epoch 23, time 1.9169, train_loss: 0.6690, test_loss: 0.6478, val_loss: 0.6502
#                      train_acc: 0.8400, test_acc: 0.7900, val_acc: 0.8400
# Epoch 24, time 1.9967, train_loss: 0.6444, test_loss: 0.6273, val_loss: 0.6343
#                      train_acc: 0.8600, test_acc: 0.8600, val_acc: 0.9000
# Epoch 25, time 1.9313, train_loss: 0.6809, test_loss: 0.5945, val_loss: 0.6009
#                      train_acc: 0.8200, test_acc: 0.8100, val_acc: 0.8600
# Epoch 26, time 1.9666, train_loss: 0.6158, test_loss: 0.5892, val_loss: 0.5906
#                      train_acc: 0.8200, test_acc: 0.9000, val_acc: 0.9000
# Epoch 27, time 1.9348, train_loss: 0.5848, test_loss: 0.5609, val_loss: 0.5691
#                      train_acc: 0.8514, test_acc: 0.8600, val_acc: 0.9000
# Epoch 28, time 1.9586, train_loss: 0.5580, test_loss: 0.5376, val_loss: 0.5488
#                      train_acc: 0.8886, test_acc: 0.9000, val_acc: 0.9100
# Epoch 29, time 1.9558, train_loss: 0.5376, test_loss: 0.5105, val_loss: 0.5170
#                      train_acc: 0.8486, test_acc: 0.9000, val_acc: 0.9100
# Epoch 30, time 1.9562, train_loss: 0.5351, test_loss: 0.4909, val_loss: 0.4930
#                      train_acc: 0.8629, test_acc: 0.9000, val_acc: 0.9100
# Epoch 31, time 2.0339, train_loss: 0.4989, test_loss: 0.4659, val_loss: 0.4715
#                      train_acc: 0.8914, test_acc: 0.9000, val_acc: 0.9100
# Epoch 32, time 1.9742, train_loss: 0.4586, test_loss: 0.4530, val_loss: 0.4605
#                      train_acc: 0.9114, test_acc: 0.9600, val_acc: 0.9400
# Epoch 33, time 1.9477, train_loss: 0.4922, test_loss: 0.4298, val_loss: 0.4348
#                      train_acc: 0.8629, test_acc: 0.9600, val_acc: 0.9400
# Epoch 34, time 2.1066, train_loss: 0.4424, test_loss: 0.4189, val_loss: 0.4244
#                      train_acc: 0.9114, test_acc: 0.9000, val_acc: 0.9100
# Epoch 35, time 1.9971, train_loss: 0.4389, test_loss: 0.3953, val_loss: 0.4029
#                      train_acc: 0.9029, test_acc: 0.9600, val_acc: 0.9400
# Epoch 36, time 1.9687, train_loss: 0.4015, test_loss: 0.3838, val_loss: 0.3929
#                      train_acc: 0.9114, test_acc: 0.9600, val_acc: 0.9400
# Epoch 37, time 1.9710, train_loss: 0.3936, test_loss: 0.3616, val_loss: 0.3637
#                      train_acc: 0.9029, test_acc: 0.9600, val_acc: 0.9300
# Epoch 38, time 1.9605, train_loss: 0.3609, test_loss: 0.3395, val_loss: 0.3455
#                      train_acc: 0.9343, test_acc: 0.9400, val_acc: 0.9400
# Epoch 39, time 2.4396, train_loss: 0.3525, test_loss: 0.3470, val_loss: 0.3540
#                      train_acc: 0.9543, test_acc: 1.0000, val_acc: 0.9700
# Epoch 40, time 2.6878, train_loss: 0.3677, test_loss: 0.3243, val_loss: 0.3328
#                      train_acc: 0.9343, test_acc: 1.0000, val_acc: 0.9800
# Epoch 41, time 2.0049, train_loss: 0.3384, test_loss: 0.3065, val_loss: 0.3132
#                      train_acc: 0.9543, test_acc: 1.0000, val_acc: 0.9700
# Epoch 42, time 1.9187, train_loss: 0.3152, test_loss: 0.3198, val_loss: 0.3351
#                      train_acc: 0.9686, test_acc: 0.9600, val_acc: 0.9700
# Epoch 43, time 1.9314, train_loss: 0.3054, test_loss: 0.2814, val_loss: 0.2852
#                      train_acc: 0.9429, test_acc: 1.0000, val_acc: 0.9800
# Epoch 44, time 1.9729, train_loss: 0.3020, test_loss: 0.2802, val_loss: 0.2833
#                      train_acc: 0.9600, test_acc: 1.0000, val_acc: 0.9700
# Epoch 45, time 1.9789, train_loss: 0.3069, test_loss: 0.2703, val_loss: 0.2726
#                      train_acc: 0.9457, test_acc: 0.9600, val_acc: 0.9700
# Epoch 46, time 1.9882, train_loss: 0.2693, test_loss: 0.2434, val_loss: 0.2462
#                      train_acc: 0.9600, test_acc: 1.0000, val_acc: 0.9700
# Epoch 47, time 2.0100, train_loss: 0.2741, test_loss: 0.2486, val_loss: 0.2543
#                      train_acc: 0.9886, test_acc: 1.0000, val_acc: 0.9800
# Epoch 48, time 1.9894, train_loss: 0.2476, test_loss: 0.2261, val_loss: 0.2310
#                      train_acc: 0.9743, test_acc: 1.0000, val_acc: 1.0000
# Epoch 49, time 2.0441, train_loss: 0.2294, test_loss: 0.2171, val_loss: 0.2204
#                      train_acc: 0.9829, test_acc: 1.0000, val_acc: 0.9800
